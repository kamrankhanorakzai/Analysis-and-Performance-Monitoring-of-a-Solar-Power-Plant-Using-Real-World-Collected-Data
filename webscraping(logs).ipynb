# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

# %%
service=Service("C:/Users/turab/Downloads/msedgedriver.exe")
deriver=webdriver.Edge(service=service)
deriver.get("https://www.cloudinverter.net/dist/#/logs")
time.sleep(30)
name=deriver.find_element(by=By.XPATH,value='/html/body/div/div/div[2]/div[2]/div/div/div[2]/div/div/form/div[1]/div/div[2]/div/div/input')
name.send_keys("Res55")  
password=deriver.find_element(by=By.XPATH,value='/html/body/div/div/div[2]/div[2]/div/div/div[2]/div/div/form/div[2]/div/div[2]/div/div/span/input')
password.send_keys("Res444")  

login_btn = deriver.find_element(By.XPATH, '/html/body/div/div/div[2]/div[2]/div/div/div[2]/div/div/form/div[4]/div/div/div/div/button[1]')
login_btn.click()
time.sleep(4)
login_btn = deriver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div/header[2]/div/div/div[2]/ul/li[2]/span/div/div")
login_btn.click()
time.sleep(18)


start_date = datetime(2025, 8, 27)
today = datetime.today().date()



while start_date.date() <= today:
    end_date = start_date + timedelta(days=6)

    # Make sure end_date doesn't go beyond today
    if end_date.date() > today:
        end_date = datetime.combine(today, datetime.min.time())

    start=start_date.strftime('%Y-%m-%d')
    end=end_date.strftime('%Y-%m-%d')
    date_range = deriver.find_element(By.CLASS_NAME, 'ant-picker-input')
    date_range.click()
    time.sleep(1)
    start_input = deriver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div/main/div/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div[1]/div/div[2]/div/div[2]/div[1]/div/div[1]/input')
    start_input.clear()
    start_input.send_keys(start)
    start_input.send_keys(Keys.ENTER)
    time.sleep(1)
    
    # Locate end date input and set value
    end_input = deriver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div/main/div/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div[1]/div/div[2]/div/div[2]/div[1]/div/div[3]/input')
    end_input.clear()
    end_input.send_keys(end)
    end_input.send_keys(Keys.ENTER)
    time.sleep(1)
    # Confirm
    ok_btn = deriver.find_element(By.XPATH, '/html/body/div/div/div/div[2]/div/main/div/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div[1]/div/div[2]/div/div[2]/div[4]/button')
    ok_btn.click()
    start_date = start_date + timedelta(days=7)
    time.sleep(5)
